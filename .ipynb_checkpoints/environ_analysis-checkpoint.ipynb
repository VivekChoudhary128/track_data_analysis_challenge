# %%
import pandas as pd
import seaborn as sns
import requests as req
import json
from scipy.stats import variation
from ipyleaflet import Map, basemaps, basemap_to_tiles, Circle
import matplotlib.pyplot as plt
from sklearn.utils import resample
# %matplotlib inline

# %%
# getting tacks for page 0 and first 100 entries 
dat = req.get('https://envirocar.org/api/stable/tracks', params={'page': 4}).json()['tracks']

# %%
# getting the ids
ids = [_['id'] for _ in dat]

# %%
# first track data
data = pd.read_csv(f'https://envirocar.org/api/stable/tracks/{ids[0]}.csv', sep=';', engine='python')
data.head()
# Out:
#                          id          CO2(kg/h)  GPS HDOP(precision)  \
# 0  5c14981c44ea850302b127ff                                     1.1
# 1  5c14981c44ea850302b12801                                     1.7
# 2  5c14981c44ea850302b12802   2.92003832880952                  1.1
# 3  5c14981c44ea850302b12803                                     1.0
# 4  5c14981c44ea850302b12804                                     1.3
#
#     GPS Altitude(m)   GPS Bearing(deg)             MAF(l/s)  \
# 0        143.151468         304.339874
# 1        142.344093         305.963837
# 2        141.856606         306.094635   3.7799999713897705
# 3        141.500532         320.720123
# 4        140.547116         342.445129
#
#       Consumption(l/h)   Speed(km/h)   GPS Speed(km/h)  Rpm(u/min)  \
# 0                               46.0         45.643612      1369.0
# 1                               46.0         45.915009
# 2   1.2425695016210723          45.0         45.495461
# 3                               45.0         44.182362      1331.0
# 4                               45.0         45.063362
#
#    Throttle Position(%)  GPS VDOP(precision)   GPS Accuracy(%)  \
# 0                                        1.2               6.0
# 1                                        1.4               8.0
# 2                                        1.2               4.0
# 3                                        1.3               3.0
# 4                                        1.5               3.0
#
#    GPS PDOP(precision)  Intake Temperature(c)  Engine Load(%)   longitude  \
# 0                  1.7                                           7.218317
# 1                  2.2                   42.0                    7.217720
# 2                  1.7                   43.0                    7.217277
# 3                  1.6                                           7.217005
# 4                  2.0                   42.0                    7.216808
#
#     latitude                   time
# 0  51.484903   2018-12-15T04:14:27Z
# 1  51.485168   2018-12-15T04:14:31Z
# 2  51.485371   2018-12-15T04:14:34Z
# 3  51.485510   2018-12-15T04:14:36Z
# 4  51.485814   2018-12-15T04:14:39Z

# %% [markdown]
# ### Processing of Empty values

# %%
single_track = pd.read_csv(f'https://envirocar.org/api/stable/tracks/{ids[0]}.csv', sep=';', engine='python')
data = single_track.copy()
# requesting data for each track

for _ in ids[1:10]:    
    data = data.append(pd.read_csv(f'https://envirocar.org/api/stable/tracks/{_}.csv', sep=';', engine='python'))

# %% [markdown]
# ### Analysis

# %%
# identifying correlation between properties
fig, ax = plt.subplots(figsize=(20,10)) 
sns.heatmap(data.corr(), linewidths=1, annot=True, ax=ax)

# %%
single_track.var()
# Out:
#  GPS Altitude(m)        27.292268
#  GPS Bearing(deg)    11876.442558
#  Speed(km/h)            53.939235
#  GPS Speed(km/h)        69.702756
#  GPS Accuracy(%)         3.366600
#  longitude               0.000003
#  latitude                0.000027
# dtype: float64

# %%
single_track.head()
# Out:
#                          id          CO2(kg/h)  GPS HDOP(precision)  \
# 0  5c14981c44ea850302b127ff                                     1.1
# 1  5c14981c44ea850302b12801                                     1.7
# 2  5c14981c44ea850302b12802   2.92003832880952                  1.1
# 3  5c14981c44ea850302b12803                                     1.0
# 4  5c14981c44ea850302b12804                                     1.3
#
#     GPS Altitude(m)   GPS Bearing(deg)             MAF(l/s)  \
# 0        143.151468         304.339874
# 1        142.344093         305.963837
# 2        141.856606         306.094635   3.7799999713897705
# 3        141.500532         320.720123
# 4        140.547116         342.445129
#
#       Consumption(l/h)   Speed(km/h)   GPS Speed(km/h)  Rpm(u/min)  \
# 0                               46.0         45.643612      1369.0
# 1                               46.0         45.915009
# 2   1.2425695016210723          45.0         45.495461
# 3                               45.0         44.182362      1331.0
# 4                               45.0         45.063362
#
#    Throttle Position(%)  GPS VDOP(precision)   GPS Accuracy(%)  \
# 0                                        1.2               6.0
# 1                                        1.4               8.0
# 2                                        1.2               4.0
# 3                                        1.3               3.0
# 4                                        1.5               3.0
#
#    GPS PDOP(precision)  Intake Temperature(c)  Engine Load(%)   longitude  \
# 0                  1.7                                           7.218317
# 1                  2.2                   42.0                    7.217720
# 2                  1.7                   43.0                    7.217277
# 3                  1.6                                           7.217005
# 4                  2.0                   42.0                    7.216808
#
#     latitude                   time
# 0  51.484903   2018-12-15T04:14:27Z
# 1  51.485168   2018-12-15T04:14:31Z
# 2  51.485371   2018-12-15T04:14:34Z
# 3  51.485510   2018-12-15T04:14:36Z
# 4  51.485814   2018-12-15T04:14:39Z

# %%
single_track.head()
# Out:
#                          id          CO2(kg/h)  GPS HDOP(precision)  \
# 0  5c14981c44ea850302b127ff                                     1.1
# 1  5c14981c44ea850302b12801                                     1.7
# 2  5c14981c44ea850302b12802   2.92003832880952                  1.1
# 3  5c14981c44ea850302b12803                                     1.0
# 4  5c14981c44ea850302b12804                                     1.3
#
#     GPS Altitude(m)   GPS Bearing(deg)             MAF(l/s)  \
# 0        143.151468         304.339874
# 1        142.344093         305.963837
# 2        141.856606         306.094635   3.7799999713897705
# 3        141.500532         320.720123
# 4        140.547116         342.445129
#
#       Consumption(l/h)   Speed(km/h)   GPS Speed(km/h)  Rpm(u/min)  \
# 0                               46.0         45.643612      1369.0
# 1                               46.0         45.915009
# 2   1.2425695016210723          45.0         45.495461
# 3                               45.0         44.182362      1331.0
# 4                               45.0         45.063362
#
#    Throttle Position(%)  GPS VDOP(precision)   GPS Accuracy(%)  \
# 0                                        1.2               6.0
# 1                                        1.4               8.0
# 2                                        1.2               4.0
# 3                                        1.3               3.0
# 4                                        1.5               3.0
#
#    GPS PDOP(precision)  Intake Temperature(c)  Engine Load(%)   longitude  \
# 0                  1.7                                           7.218317
# 1                  2.2                   42.0                    7.217720
# 2                  1.7                   43.0                    7.217277
# 3                  1.6                                           7.217005
# 4                  2.0                   42.0                    7.216808
#
#     latitude                   time
# 0  51.484903   2018-12-15T04:14:27Z
# 1  51.485168   2018-12-15T04:14:31Z
# 2  51.485371   2018-12-15T04:14:34Z
# 3  51.485510   2018-12-15T04:14:36Z
# 4  51.485814   2018-12-15T04:14:39Z

# %% [markdown]
# ### Single Track

# %%
layer = basemap_to_tiles(basemaps.Stamen.Toner)
m = Map(zoom=13, center=(single_track[' latitude'][0], single_track[' longitude'][0]))

col = int("8a2be2", 16)

for i, j, k in zip(single_track[' longitude'][1:], single_track[' latitude'][1:], single_track[' GPS Speed(km/h)'][1:]):
    circle = Circle()
    circle.location = (j, i)
    circle.radius = 2
    circle.color = '#' + str(hex(int(float(col) + float(k) * 5.0)))[2:]
    m.add_layer(circle)
m
# Out:
# Map(basemap={'url': 'https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', 'max_zoom': 19, 'attribution': 'Map data (c) <a href="https://openstreetmap.org">OpenStreetMap</a> contributors'}, center=[51.48490322881696, 7.218317306206355], layers=(TileLayer(base=True, max_zoom=19, min_zoom=1, options=['attribution', 'detect_retina', 'max_zoom', 'min_zoom', 'tile_size']), Circle(color='#8a2cc7', location=[51.48516844268341, 7.217719760749289], options=['class_name', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=2), Circle(color='#8a2cc5', location=[51.48537054551639, 7.2172769667615775], options=['class_name', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=2), Circle(color='#8a2cbe', location=[51.485509631176306, 7.217005195280022], options=['class_name', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=2), Circle(color='#8a2cc3', location=[51.48581357966361, 7.216807880688488], options=['class_name', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=2), Circle(color='#8a2cb6', location=[51.48613429902411, 7.216675133339522], options=['class_name', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=2), Circle(color='#8a2cb0', location=[51.48633590371515, 7.216580958208697], options=['class_name', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=2), Circle(color='#8a2caf', location=[51.48654054000159, 7.216480077791724], options=['class_name', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=2), Circle(color='#8a2cad', location=[51.48663694255826, 7.216424744132162], options=['class_name', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=2), Circle(color='#8a2ca8', location=[51.48682343642224, 7.216304473001945], options=['class_name', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=2), Circle(color='#8a2cab', location=[51.48691786052045, 7.216238873932482], options=['class_name', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=2), Circle(color='#8a2caa', location=[51.48710721157864, 7.216105843955053], options=['class_name', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=2), Circle(color='#8a2cb0', location=[51.48730611607007, 7.216014450427912], options=['class_name', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=2), Circle(color='#8a2cb3', location=[51.48741169285832, 7.2159800741265725], options=['class_name', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=2), Circle(color='#8a2cad', location=[51.48770734869779, 7.215799412259715], options=['class_name', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=2), Circle(color='#8a2ca1', location=[51.48780652519842, 7.215522432347204], options=['cl ...

# %% [markdown]
# ### Multiple Tracks

# %%
layer = basemap_to_tiles(basemaps.Stamen.Toner)
lat = data[' latitude'].tolist()
lon = data[' longitude'].tolist()
spe = data[' GPS Speed(km/h)'].tolist()

m = Map(zoom=13, center=(lat[0], lon[0]))

col = int("8a2be2", 16)

for i, j, k in zip(lat[1:], lon[1:], spe[1:]):
    circle = Circle()
    circle.location = (i, j)
    circle.radius = 2
    circle.color = '#' + str(hex(int(float(col) + float(k) * 5.0)))[2:]
    m.add_layer(circle)
m
# Out:
# Map(basemap={'url': 'https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', 'max_zoom': 19, 'attribution': 'Map data (c) <a href="https://openstreetmap.org">OpenStreetMap</a> contributors'}, center=[7.218317306206355, 7.218317306206355], layers=(TileLayer(base=True, max_zoom=19, min_zoom=1, options=['attribution', 'detect_retina', 'max_zoom', 'min_zoom', 'tile_size']), Circle(color='#8a2cc7', location=[7.217719760749289, 7.217719760749289], options=['class_name', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=2), Circle(color='#8a2cc5', location=[7.2172769667615775, 7.2172769667615775], options=['class_name', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=2), Circle(color='#8a2cbe', location=[7.217005195280022, 7.217005195280022], options=['class_name', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=2), Circle(color='#8a2cc3', location=[7.216807880688488, 7.216807880688488], options=['class_name', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=2), Circle(color='#8a2cb6', location=[7.216675133339522, 7.216675133339522], options=['class_name', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=2), Circle(color='#8a2cb0', location=[7.216580958208697, 7.216580958208697], options=['class_name', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=2), Circle(color='#8a2caf', location=[7.216480077791724, 7.216480077791724], options=['class_name', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=2), Circle(color='#8a2cad', location=[7.216424744132162, 7.216424744132162], options=['class_name', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=2), Circle(color='#8a2ca8', location=[7.216304473001945, 7.216304473001945], options=['class_name', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=2), Circle(color='#8a2cab', location=[7.216238873932482, 7.216238873932482], options=['class_name', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=2), Circle(color='#8a2caa', location=[7.216105843955053, 7.216105843955053], options=['class_name', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=2), Circle(color='#8a2cb0', location=[7.216014450427912, 7.216014450427912], options=['class_name', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=2), Circle(color='#8a2cb3', location=[7.2159800741265725, 7.2159800741265725], options=['class_name', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=2), Circle(color='#8a2cad', location=[7.215799412259715, 7.215799412259715], options=['class_name', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=2), Circle(color='#8a2ca1', location=[7.215522432347204, 7.215522432347204], options=['c ...

# %% [markdown]
# # Package Directory

# %% [raw]
# enviro_car
#     |
#     |--Ecar
#     |     |
#     |     |--visual
#     |     |    |
#     |     |    |--define_graph.py
#     |     |    |--plot_current.py
#     |     |    |--init.py
#     |     |    |...
#     |     |--services
#     |     |    |
#     |     |    |--open.py
#     |     |    |--plot_current.py
#     |     |    |--init.py
#     |     |    |...
#     |     |--endpoints
#     |     |    |
#     |     |    |--init.py
#     |     |    |--user.py
#     |     |    |--sensor.py
#     |     |    |--init.py
#     |     |    |--measurement.py
#     |     |    |--track.py
#     |     |    |...
#     |     |
#     |     |--Licence
#     |     |--ReadMe.Md
#     |     |--setup.py

# %% [markdown]
# ## Further Ideas

# %%
###
