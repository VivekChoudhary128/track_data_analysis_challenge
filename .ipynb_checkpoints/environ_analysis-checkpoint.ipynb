# %%
import pandas as pd
import seaborn as sns
import requests as req
import json
from scipy.stats import variation
from ipyleaflet import Map, basemaps, basemap_to_tiles, Circle
import matplotlib.pyplot as plt
from sklearn.utils import resample
# %matplotlib inline

# %%
# getting tacks for page 0 and first 100 entries 
dat = req.get('https://envirocar.org/api/stable/tracks', params={'page': 4}).json()['tracks']

# %%
# getting the ids
ids = [_['id'] for _ in dat]

# %%
# first track data
data = pd.read_csv(f'https://envirocar.org/api/stable/tracks/{ids[0]}.csv', sep=';', engine='python')
data.head()
# Out:
#                          id            CO2(kg/h)   GPS Altitude(m)  \
# 0  5c14983044ea850302b128d8                             126.456921
# 1  5c14983044ea850302b128da                             126.320146
# 2  5c14983044ea850302b128db   4.4341321338318656        126.184402
# 3  5c14983044ea850302b128dc                             126.161344
# 4  5c14983044ea850302b128dd                             126.096456
#
#    GPS HDOP(precision)   GPS Bearing(deg)     Consumption(l/h)  \
# 0                  1.6           2.282451
# 1                  1.1         357.988800
# 2                  1.4         358.158539   1.8868647378007937
# 3                  0.9         355.355194
# 4                  0.9         350.870148
#
#              MAF(l/s)   Speed(km/h)   GPS Speed(km/h)  Rpm(u/min)  \
# 0                              30.0         30.486065      1444.0
# 1                              30.0         30.715256      1453.0
# 2   5.739999771118164          30.0         30.743151
# 3                              30.0         30.998093      1485.0
# 4                              31.0         31.599148      1503.0
#
#    Throttle Position(%)  GPS VDOP(precision)   GPS Accuracy(%)  \
# 0                  16.0                  2.2               3.0
# 1                                        1.4               3.0
# 2                  17.0                  2.4               3.0
# 3                                        1.4               3.0
# 4                                        1.4               3.0
#
#    GPS PDOP(precision)  Intake Temperature(c)       Engine Load(%)  \
# 0                  2.7                          23.921567916870117
# 1                  1.8                   44.0
# 2                  2.8                   44.0
# 3                  1.6                           26.66666603088379
# 4                  1.6                   44.0
#
#     longitude   latitude                   time
# 0    7.212854  51.504330   2018-12-15T04:25:45Z
# 1    7.212846  51.504483   2018-12-15T04:25:47Z
# 2    7.212831  51.504639   2018-12-15T04:25:49Z
# 3    7.212823  51.504719   2018-12-15T04:25:50Z
# 4    7.212780  51.504881   2018-12-15T04:25:52Z

# %% [markdown]
# ### Processing of Empty values

# %%
single_track = pd.read_csv(f'https://envirocar.org/api/stable/tracks/{ids[0]}.csv', sep=';', engine='python')
data = single_track.copy()
# requesting data for each track

for _ in ids[1:10]:    
    data = data.append(pd.read_csv(f'https://envirocar.org/api/stable/tracks/{_}.csv', sep=';', engine='python'))

# %% [markdown]
# ### Analysis

# %%
# identifying correlation between properties
fig, ax = plt.subplots(figsize=(20,10)) 
sns.heatmap(data.corr(), linewidths=1, annot=True, ax=ax)

# %%
# variance 
single_track.var()
# Out:
#  GPS Altitude(m)        83.134763
#  GPS Bearing(deg)    24838.400934
#  Speed(km/h)          1217.844668
#  GPS Speed(km/h)      1241.960221
#  GPS Accuracy(%)         1.205870
#  longitude               0.001229
#  latitude                0.012921
# dtype: float64

# %%
single_track.head()
# Out:
#                          id            CO2(kg/h)   GPS Altitude(m)  \
# 0  5c14983044ea850302b128d8                             126.456921
# 1  5c14983044ea850302b128da                             126.320146
# 2  5c14983044ea850302b128db   4.4341321338318656        126.184402
# 3  5c14983044ea850302b128dc                             126.161344
# 4  5c14983044ea850302b128dd                             126.096456
#
#    GPS HDOP(precision)   GPS Bearing(deg)     Consumption(l/h)  \
# 0                  1.6           2.282451
# 1                  1.1         357.988800
# 2                  1.4         358.158539   1.8868647378007937
# 3                  0.9         355.355194
# 4                  0.9         350.870148
#
#              MAF(l/s)   Speed(km/h)   GPS Speed(km/h)  Rpm(u/min)  \
# 0                              30.0         30.486065      1444.0
# 1                              30.0         30.715256      1453.0
# 2   5.739999771118164          30.0         30.743151
# 3                              30.0         30.998093      1485.0
# 4                              31.0         31.599148      1503.0
#
#    Throttle Position(%)  GPS VDOP(precision)   GPS Accuracy(%)  \
# 0                  16.0                  2.2               3.0
# 1                                        1.4               3.0
# 2                  17.0                  2.4               3.0
# 3                                        1.4               3.0
# 4                                        1.4               3.0
#
#    GPS PDOP(precision)  Intake Temperature(c)       Engine Load(%)  \
# 0                  2.7                          23.921567916870117
# 1                  1.8                   44.0
# 2                  2.8                   44.0
# 3                  1.6                           26.66666603088379
# 4                  1.6                   44.0
#
#     longitude   latitude                   time
# 0    7.212854  51.504330   2018-12-15T04:25:45Z
# 1    7.212846  51.504483   2018-12-15T04:25:47Z
# 2    7.212831  51.504639   2018-12-15T04:25:49Z
# 3    7.212823  51.504719   2018-12-15T04:25:50Z
# 4    7.212780  51.504881   2018-12-15T04:25:52Z

# %% [markdown]
# ### Single Track

# %%
layer = basemap_to_tiles(basemaps.Stamen.Toner)
m = Map(zoom=13, center=(single_track[' latitude'][0], single_track[' longitude'][0]))

col = int("8a2be2", 16)

for i, j, k in zip(single_track[' longitude'][1:], single_track[' latitude'][1:], single_track[' GPS Speed(km/h)'][1:]):
    circle = Circle()
    circle.location = (j, i)
    circle.radius = 2
    circle.color = '#' + str(hex(int(float(col) + float(k) * 5.0)))[2:]
    m.add_layer(circle)
m
# Out:
# Map(basemap={'url': 'https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', 'max_zoom': 19, 'attribution': 'Map data (c) <a href="https://openstreetmap.org">OpenStreetMap</a> contributors'}, center=[51.504329687877544, 7.212854079978423], layers=(TileLayer(base=True, max_zoom=19, min_zoom=1, options=['attribution', 'detect_retina', 'max_zoom', 'min_zoom', 'tile_size']), Circle(color='#8a2c7b', location=[51.504482786514814, 7.212845847755699], options=['class_name', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=2), Circle(color='#8a2c7b', location=[51.504639448901436, 7.212831037357532], options=['class_name', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=2), Circle(color='#8a2c7c', location=[51.50471908551486, 7.212823223350996], options=['class_name', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=2), Circle(color='#8a2c7f', location=[51.50488110164735, 7.212780462833259], options=['class_name', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=2), Circle(color='#8a2c81', location=[51.505041191100084, 7.212721382713398], options=['class_name', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=2), Circle(color='#8a2c81', location=[51.50511879772623, 7.212686704122447], options=['class_name', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=2), Circle(color='#8a2c7e', location=[51.5052723152927, 7.212633315097968], options=['class_name', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=2), Circle(color='#8a2c7d', location=[51.505422266520945, 7.212586884112808], options=['class_name', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=2), Circle(color='#8a2c7d', location=[51.50549791862086, 7.212561273902099], options=['class_name', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=2), Circle(color='#8a2c7c', location=[51.5056547207032, 7.212502163004394], options=['class_name', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=2), Circle(color='#8a2c7a', location=[51.50580651891833, 7.2124434167583615], options=['class_name', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=2), Circle(color='#8a2c76', location=[51.50595388746418, 7.212380162346972], options=['class_name', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=2), Circle(color='#8a2c74', location=[51.50602549434764, 7.2123565373072775], options=['class_name', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=2), Circle(color='#8a2c76', location=[51.50617045466282, 7.212305330725933], options=['class_name', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=2), Circle(color='#8a2c73', location=[51.50631611406435, 7.212263799524228], options=[' ...

# %% [markdown]
# ### Multiple Tracks

# %%
## The colour gradient determines the speed of each record 
## of the respective track
layer = basemap_to_tiles(basemaps.Stamen.Toner)
lat = data[' latitude'].tolist()
lon = data[' longitude'].tolist()
spe = data[' GPS Speed(km/h)'].tolist()

m = Map(zoom=13, center=(lat[0], lon[0]))

col = int("8a2be2", 16)

for i, j, k in zip(lat[1:], lon[1:], spe[1:]):
    circle = Circle()
    circle.location = (i, j)
    circle.radius = 2
    circle.color = '#' + str(hex(int(float(col) + float(k) * 5.0)))[2:]
    m.add_layer(circle)
m
# Out:
# Map(basemap={'url': 'https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', 'max_zoom': 19, 'attribution': 'Map data (c) <a href="https://openstreetmap.org">OpenStreetMap</a> contributors'}, center=[51.504329687877544, 7.212854079978423], layers=(TileLayer(base=True, max_zoom=19, min_zoom=1, options=['attribution', 'detect_retina', 'max_zoom', 'min_zoom', 'tile_size']), Circle(color='#8a2c7b', location=[51.504482786514814, 7.212845847755699], options=['class_name', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=2), Circle(color='#8a2c7b', location=[51.504639448901436, 7.212831037357532], options=['class_name', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=2), Circle(color='#8a2c7c', location=[51.50471908551486, 7.212823223350996], options=['class_name', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=2), Circle(color='#8a2c7f', location=[51.50488110164735, 7.212780462833259], options=['class_name', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=2), Circle(color='#8a2c81', location=[51.505041191100084, 7.212721382713398], options=['class_name', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=2), Circle(color='#8a2c81', location=[51.50511879772623, 7.212686704122447], options=['class_name', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=2), Circle(color='#8a2c7e', location=[51.5052723152927, 7.212633315097968], options=['class_name', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=2), Circle(color='#8a2c7d', location=[51.505422266520945, 7.212586884112808], options=['class_name', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=2), Circle(color='#8a2c7d', location=[51.50549791862086, 7.212561273902099], options=['class_name', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=2), Circle(color='#8a2c7c', location=[51.5056547207032, 7.212502163004394], options=['class_name', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=2), Circle(color='#8a2c7a', location=[51.50580651891833, 7.2124434167583615], options=['class_name', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=2), Circle(color='#8a2c76', location=[51.50595388746418, 7.212380162346972], options=['class_name', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=2), Circle(color='#8a2c74', location=[51.50602549434764, 7.2123565373072775], options=['class_name', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=2), Circle(color='#8a2c76', location=[51.50617045466282, 7.212305330725933], options=['class_name', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=2), Circle(color='#8a2c73', location=[51.50631611406435, 7.212263799524228], options=[' ...

# %% [markdown]
# # Package Directory

# %% [raw]
# enviro_car
#     |
#     |--Ecar
#     |     |
#     |     |--visual
#     |     |    |
#     |     |    |--define_graph.py
#     |     |    |--plot_current.py
#     |     |    |--init.py
#     |     |    |...
#     |     |--services
#     |     |    |
#     |     |    |--open.py
#     |     |    |--plot_current.py
#     |     |    |--init.py
#     |     |    |...
#     |     |--endpoints
#     |     |    |
#     |     |    |--init.py
#     |     |    |--user.py
#     |     |    |--sensor.py
#     |     |    |--init.py
#     |     |    |--measurement.py
#     |     |    |--track.py
#     |     |    |...
#     |     |--tests
#     |     |   |
#     |     |   |--init.py
#     |     |   |--cumm_pllt_test.py
#     |     |   |--api_respose_colab.py
#     |     |   |--..
#     |     |   |
#     |     |--Licence
#     |     |--ReadMe.Md
#     |     |--setup.py

# %% [markdown]
# ## Further Ideas

# %% [markdown]
# ### Analyzing Emmision rate of a car

# %% [markdown]
# From the track api we can deduce that that we don't get Co2 emmision of each and and every entry of a specific track, furthermore, the currently presented Co2 figures are in string format in place of float.
#
# If we see this as an interest of data visualising problem it can be problematic as we can find any relation of Co2 emmisions to any other sensor data.
#
# Hence, a work around can be filling out the values of each empty car track data with mean from the current available data in the api on the basis of identical tracks with similar factors like: car type/company, RPM, Average speed altitute etc.

# %% [markdown]
# ### Car health check

# %% [raw]
# Car health check (CHC) is about checking and regularing the car performance according to it's output in subsequent days.
#
# A data of each user's car will be monitored and in the end of the day a report will be generated or his/her car's output, and a subsequent graph with it's previous outputs will be given, the graphs resets at each service done, but comparisons from previous stats can be done, if the performance if degrading in a faster then before than it is a concern a notification will be given.
#
# further, extra maintainance advices will be given, the behalf of the data.

# %%
# Best regards :)
